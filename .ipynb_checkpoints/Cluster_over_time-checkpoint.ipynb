# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.mixture import GaussianMixture
from matplotlib.patches import Ellipse
from tqdm import tqdm
from scipy.ndimage import gaussian_filter
from skimage import measure
from getParameters import get_gait_parameters_insole
from getParameters import gait_aligned_jnt
from pre import butter_lowpass_filter
from DataManager import DataManager
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# %% [markdown]
# # Functions

# %%
def plot_insole_grid(grid):
    fig = plt.figure(figsize = (8,4))
    plt.imshow(reshape_insole_grid(insoleAll_l[0]), cmap='viridis', interpolation='nearest')
    plt.colorbar(label='Pixel intensity')
    plt.title('64x16 Array Pixel Representation')
    # plt.show()
    return fig

def reshape_insole_grid(data):
    data = data.reshape(16,64).T.copy()
    data[:32,] = np.flipud(data[:32,])
    return data

def filter_coordinates(grid, threshold = 0):
    return np.argwhere(grid > threshold)

def calculate_centroid(grid_data, region_threshold = 0, apply_GF = False, return_fig = False):
    if apply_GF:
        # Apply a Gaussian filter to smooth the data slightly
        smoothed_data = gaussian_filter(grid_data, sigma=1)
        smoothed_data = grid_data
    else:
        smoothed_data = grid_data
    
    # This threshold is set to detect significant pressure areas, typically in toes and heels
    threshold = np.mean(smoothed_data) - 0.05 * np.std(smoothed_data)
    binary_data = smoothed_data > threshold
    
    # Identify regions (blobs) in the binary data
    # Label the regions for boundary detection
    labels = measure.label(binary_data, connectivity=2)
    regions = measure.regionprops(labels)
    
    # Calculate the centroids for each labeled region (non-zero class)
    centroids = []
    
    for region in regions:
        # Ensure the region is significant in size
        if region.area >= region_threshold:
            centroids.append(region.centroid)

    if return_fig:
        # Plot the original data with detected boundaries overlayed
        fig, ax = plt.subplots()
        ax.imshow(smoothed_data, cmap='viridis')
        ax.set_title("Toes and Heels AOI", pad=20)
        
        # Draw boundaries around regions (toes and heels likely)
        for region in regions:
            # Exclude very small regions to focus on main areas
            if region.area >= region_threshold:  # Arbitrary minimum area threshold for significant region
                # Get boundary coordinates
                for coord in region.coords:
                    ax.plot(coord[1], coord[0], marker="o", color="yellow", markersize=5, alpha = 0.3)
        
        # Draw red areas for centroids of each significant region
        for centroid in centroids:
            # Plot a small red area around the centroid position
            ax.add_patch(plt.Circle((centroid[1], centroid[0]), radius=1, color='red', alpha=1))
        
        plt.colorbar(ax.imshow(grid_data, cmap='viridis'), label="Pressure Intensity", pad=0.02)
        plt.xlabel("Width")
        plt.ylabel("Length")
        plt.tight_layout()
        # plt.show()
        plt.close()

        return centroids, labels, fig
        
    else:
        return centroids, labels

def GM_cluster(grid_data, cluster_num = 5, apply_GF = False, return_fig = False):
    
    if apply_GF:
        # Apply a Gaussian filter to smooth the data slightly
        smoothed_data = gaussian_filter(grid_data, sigma=1)
        smoothed_data = grid_data
    else:
        smoothed_data = grid_data
    
    # This threshold is set to detect significant pressure areas, typically in toes and heels
    threshold = np.mean(smoothed_data) - 0.05 * np.std(smoothed_data)

    grid_coord = filter_coordinates(smoothed_data, threshold = threshold)
    
    gmm = GaussianMixture(n_components=cluster_num, covariance_type='full', random_state=42)
    gmm.fit(grid_coord)
    labels = gmm.predict(grid_coord)
    
    # Get the means (cluster centers) and covariances from the GMM
    means = gmm.means_
    covariances = gmm.covariances_

    if return_fig:
        fig = plt.figure(figsize = (4,12))
        
        # Plot the original coordinates and clustering
        plt.scatter(grid_coord[:, 1], grid_coord[:, 0], s=10, label='Activated Sensors', c = labels)
        
        # Plot the clustering centers
        plt.scatter(means[:, 1], means[:, 0], c='red', marker='x', s=100, label='Cluster Centers')
        
        for i, (mean, cov) in enumerate(zip(means, covariances)):
            # Compute the eigenvalues and eigenvectors for the covariance matrix
            eigenvalues, eigenvectors = np.linalg.eigh(cov)
            
            # Compute the angle for the ellipse
            angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))
            
            # Width and height of the ellipse correspond to the 95% confidence interval
            width, height = 2 * np.sqrt(eigenvalues) * 1.96
            
            # Create and add the ellipse patch
            ellipse = Ellipse((mean[1],mean[0]), width, height, angle = angle,edgecolor='red', facecolor='none', linestyle='--')
            plt.gca().add_patch(ellipse)
        
        plt.title(f'Gaussian Mixture Model Clustering with 95% Confidence\n Intervals with {cluster_num} Clusters')
        plt.legend()
        plt.xlim(0, 16)
        plt.ylim(0, 64)
        plt.gca().invert_yaxis()
        plt.ioff()
        plt.close()
    
        return fig, means, covariances
    else:
        return means, covariances

# %%
def combine_plot(grid_data, region_threshold = 0, cluster_num = 5, apply_GF = False, return_fig = False):
    if apply_GF:
        # Apply a Gaussian filter to smooth the data slightly
        smoothed_data = gaussian_filter(grid_data, sigma=1)
        smoothed_data = grid_data
    else:
        smoothed_data = grid_data
    
    # This threshold is set to detect significant pressure areas, typically in toes and heels
    threshold = np.mean(smoothed_data) - 0.05 * np.std(smoothed_data)
    binary_data = smoothed_data > threshold
    
    # Identify regions (blobs) in the binary data
    # Label the regions for boundary detection
    labels = measure.label(binary_data, connectivity=2)
    regions = measure.regionprops(labels)
    
    # Calculate the centroids for each labeled region (non-zero class)
    centroids = []
    
    for region in regions:
        # Ensure the region is significant in size
        if region.area >= region_threshold:
            centroids.append(region.centroid)


    # Clustering based on GMM
    grid_coord = filter_coordinates(smoothed_data, threshold = threshold)
    
    gmm = GaussianMixture(n_components=cluster_num, covariance_type='full', random_state=42)
    gmm.fit(grid_coord)
    GMM_labels = gmm.predict(grid_coord)
    
    # Get the means (cluster centers) and covariances from the GMM
    means = gmm.means_
    covariances = gmm.covariances_

    if return_fig:
        # Plot the original data with detected boundaries overlayed
        fig, ax = plt.subplots()
        ax.imshow(smoothed_data, cmap='viridis')
        ax.set_title("Toes and Heels AOI", pad=20)
        
        # Draw boundaries around regions (toes and heels likely)
        for region in regions:
            # Exclude very small regions to focus on main areas
            if region.area >= region_threshold:  # Arbitrary minimum area threshold for significant region
                # Get boundary coordinates
                for coord in region.coords:
                    ax.plot(coord[1], coord[0], marker="o", color="yellow", markersize=5, alpha = 0.3)
        
        # Draw red areas for centroids of each significant region
        for centroid in centroids:
            # Plot a small red area around the centroid position
            ax.add_patch(plt.Circle((centroid[1], centroid[0]), radius=1, color='red', alpha=1))

        # Draw clusters based on GMM
        for i, (mean, cov) in enumerate(zip(means, covariances)):
            # Compute the eigenvalues and eigenvectors for the covariance matrix
            eigenvalues, eigenvectors = np.linalg.eigh(cov)
            
            # Compute the angle for the ellipse
            angle = np.degrees(np.arctan2(*eigenvectors[:, 0][::-1]))
            
            # Width and height of the ellipse correspond to the 95% confidence interval
            width, height = 2 * np.sqrt(eigenvalues) * 1.96
            
            # Create and add the ellipse patch
            ellipse = Ellipse((mean[1],mean[0]), width, height, angle = angle,edgecolor='red', facecolor='none', linestyle='--')
            plt.gca().add_patch(ellipse)
        
        plt.colorbar(ax.imshow(grid_data, cmap='viridis'), label="Pressure Intensity", pad=0.02)
        plt.xlabel("Width")
        plt.ylabel("Length")
        plt.tight_layout()
        # plt.show()
        plt.close()

        return centroids, labels, fig
        
    else:
        return centroids, labels

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Trial 1

# %%
#%%
DM = DataManager()
# available_ID_list = DM.ID_list #Get all available list
available_ID_list = ['GAIT102324-01'] # or type in manually
valid_files = DM.get_valid_data_file_dict(available_ID_list)

# Set up investigation dataset
viewer_idx = 0
file = valid_files[viewer_idx]
data = sio.loadmat(file['path'])
insoleAll_l = data['insoleAll_l'].astype(np.float64)
insoleAll_r = data['insoleAll_r'].astype(np.float64)
t_insole_l = data['t_insole_l'].astype(np.float64)
t_insole_r = data['t_insole_r'].astype(np.float64)

# centroids_list = []
# interval_length = 200
# for i in tqdm(range(0, insoleAll_l.shape[0], 200)):
#     grid = reshape_insole_grid(insoleAll_l[i])
#     centroids, labels = calculate_centroid(grid)
#     centroids_list.append(centroids)

# %%
centroids, labels, fig = combine_plot(reshape_insole_grid(insoleAll_l[1030]), region_threshold = 5, cluster_num = 5, return_fig = True, apply_GF=False)
fig
# Out:
# C:\Users\jackz\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
centroids, labels, fig = calculate_centroid(reshape_insole_grid(insoleAll_l[1030]), region_threshold = 5, return_fig = True, apply_GF=False)
fig

# %%
fig, means,covs = GM_cluster(reshape_insole_grid(insoleAll_l[1030]), cluster_num = 5, return_fig = True)
fig
# Out:
# C:\Users\jackz\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# ## Trial 2

# %%
#%%
DM = DataManager()
# available_ID_list = DM.ID_list #Get all available list
available_ID_list = ['GAIT102424-01'] # or type in manually
valid_files = DM.get_valid_data_file_dict(available_ID_list)

# Set up investigation dataset
viewer_idx = 1
file = valid_files[viewer_idx]
data = sio.loadmat(file['path'])
insoleAll_l = data['insoleAll_l'].astype(np.float64)
insoleAll_r = data['insoleAll_r'].astype(np.float64)
t_insole_l = data['t_insole_l'].astype(np.float64)
t_insole_r = data['t_insole_r'].astype(np.float64)

# %%
centroids, labels, fig = combine_plot(reshape_insole_grid(insoleAll_l[660]), region_threshold = 5, cluster_num = 5, return_fig = True, apply_GF=False)
fig
# Out:
# C:\Users\jackz\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
centroids, labels, fig = calculate_centroid(reshape_insole_grid(insoleAll_l[660]), region_threshold = 5, return_fig = True, apply_GF=False)
fig

# %%
fig, means,covs = GM_cluster(reshape_insole_grid(insoleAll_l[660]), cluster_num = 5, return_fig = True)
fig
# Out:
# C:\Users\jackz\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# ## Trail 3

# %%
#%%
DM = DataManager()
# available_ID_list = DM.ID_list #Get all available list
available_ID_list = ['GAIT102424-02'] # or type in manually
valid_files = DM.get_valid_data_file_dict(available_ID_list)

# Set up investigation dataset
viewer_idx = 1
file = valid_files[viewer_idx]
data = sio.loadmat(file['path'])
insoleAll_l = data['insoleAll_l'].astype(np.float64)
insoleAll_r = data['insoleAll_r'].astype(np.float64)
t_insole_l = data['t_insole_l'].astype(np.float64)
t_insole_r = data['t_insole_r'].astype(np.float64)

# %%
centroids, labels, fig = combine_plot(reshape_insole_grid(insoleAll_l[1072]), region_threshold = 5, cluster_num = 5, return_fig = True, apply_GF=False)
fig
# Out:
# C:\Users\jackz\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
centroids, labels, fig = calculate_centroid(reshape_insole_grid(insoleAll_l[1072]), region_threshold = 5, return_fig = True, apply_GF=True)
fig

# %%
fig, means,covs = GM_cluster(reshape_insole_grid(insoleAll_l[1072]), cluster_num = 5, return_fig = True)
fig
# Out:
# C:\Users\jackz\.conda\envs\DL\lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %% [markdown]
# # Stack Over time

# %%
#%%
DM = DataManager()
# available_ID_list = DM.ID_list #Get all available list
available_ID_list = ['GAIT102324-01'] # or type in manually
valid_files = DM.get_valid_data_file_dict(available_ID_list)

# Set up investigation dataset
viewer_idx = 0
file = valid_files[viewer_idx]
data = sio.loadmat(file['path'])
insoleAll_l = data['insoleAll_l'].astype(np.float64)
insoleAll_r = data['insoleAll_r'].astype(np.float64)
t_insole_l = data['t_insole_l'].astype(np.float64)
t_insole_r = data['t_insole_r'].astype(np.float64)

centroids_list = []
interval_length = 200
for i in tqdm(range(0, insoleAll_l.shape[0], 200)):
    grid = reshape_insole_grid(insoleAll_l[i])
    centroids, labels = calculate_centroid(grid,region_threshold = 5)
    centroids_list.append(centroids)
# Out:
# 100%|██████████| 63/63 [00:00<00:00, 815.10it/s]

# %%
region1_list = [] # 0 - 20 Toes
region2_list = [] # 20 - 40 # Middle
region3_list = [] # 40 - 64 # Heals
for centroid in centroids_list:
    region1 = []
    region2 = []
    region3 = []
    
    if len(centroid) > 0:
        for coord in centroid:
            if coord[0] <= 20:
                region1.append(coord)
            elif coord[0] <= 40:
                region2.append(coord)
            else:
                region3.append(coord)

    region1_list.append(region1)
    region2_list.append(region2)
    region3_list.append(region3)

# %%
region1_list
# Out:
# [[],
#  [],
#  [],
#  [(6.380952380952381, 11.476190476190476)],
#  [(15.0, 5.0)],
#  [(5.833333333333333, 12.833333333333334)],
#  [(8.741935483870968, 12.35483870967742), (15.0, 6.0)],
#  [],
#  [],
#  [],
#  [],
#  [(8.615384615384615, 12.538461538461538),
#   (18.142857142857142, 5.714285714285714)],
#  [],
#  [(14.8, 6.3)],
#  [(6.411764705882353, 11.823529411764707)],
#  [(8.96875, 12.5), (15.0, 6.5)],
#  [],
#  [],
#  [],
#  [(8.25, 12.25), (15.0, 6.5)],
#  [(6.106060606060606, 10.43939393939394)],
#  [(6.733333333333333, 12.8)],
#  [],
#  [],
#  [],
#  [(6.339449541284404, 8.642201834862385),
#   (17.92233009708738, 5.427184466019417)],
#  [(6.75, 13.125)],
#  [(7.769230769230769, 12.076923076923077),
#   (14.733333333333333, 7.733333333333333)],
#  [],
#  [(14.777777777777779, 5.888888888888889)],
#  [(5.838709677419355, 8.623655913978494),
#   (18.43859649122807, 6.175438596491228)],
#  [(15.0, 12.5)],
#  [(8.655172413793103, 12.310344827586206)],
#  [(6.790322580645161, 9.741935483870968)],
#  [(15.0, 12.5)],
#  [(14.833333333333334, 5.0)],
#  [(7.245614035087719, 10.929824561403509)],
#  [],
#  [(8.242424242424242, 12.212121212121213)],
#  [],
#  [],
#  [(8.454545454545455, 12.181818181818182), (17.0, 7.5)],
#  [(6.0, 8.666666666666666), (16.136363636363637, 5.818181818181818)],
#  [(6.875, 12.25)],
#  [(9.363636363636363, 12.909090909090908)],
#  [(15.35598705501618, 7.627831715210356)],
#  [],
#  [],
#  [],
#  [(6.028301886792453, 8.660377358490566), (16.0, 3.5), (16.5, 8.0)],
#  [(6.5, 12.8)],
#  [(8.466666666666667, 12.933333333333334), (17.0, 7.0)],
#  [],
#  [(6.166666666666667, 13.166666666666666)],
#  [(2.0, 10.0), (6.875, 9.765625)],
#  [(7.65, 12.6)],
#  [(8.857142857142858, 12.428571428571429), (15.0, 5.0)],
#  [(2.0, 8.5), (15.0, 12.5)],
#  [(8.2, 12.133333333333333)],
#  [(7.981481481481482, 10.962962962962964)],
#  [],
#  [(9.363636363636363, 12.545454545454545)],
#  []]

# %%
def plot_coordinates_with_cmap(coordinate_list, region = ''):
    """
    Plot a list of coordinates on a grid using a colormap for the points.

    Args:
    - coordinate_list: List of lists containing tuples of coordinates.
    - grid_size: Tuple specifying the size of the grid (width, height).
    - cmap: Colormap to use for the points.
    """
    template_grid = 200*np.ones((64, 16))
    
    fig, ax = plt.subplots()
    ax.imshow(template_grid, cmap='viridis')
    ax.set_title("Toes and Heels AOI", pad=20)
    

    # Plot the coordinates with colormap
    all_coords = [coord for sublist in coordinate_list for coord in sublist]
    for idx, (x, y) in enumerate(all_coords):
        ax.add_patch(plt.Circle((y, x), radius=0.5, color='yellow', alpha=0.5))

    # Label the axes
    ax.set_title(f"Centroids for {region}")
    ax.axhline(y=20, color='red', linestyle='--', linewidth=1.5, label=f'Seperation Line')
    ax.axhline(y=40, color='red', linestyle='--', linewidth=1.5, label=f'Seperation Line')

    plt.close()

    return fig

# %%
# Plot the coordinates on a 64x16 grid with colormap
fig = plot_coordinates_with_cmap(region1_list, region = 'toe area')
fig

# %%
# Plot the coordinates on a 64x16 grid with colormap
fig = plot_coordinates_with_cmap(region2_list, region = 'midfoot area')
fig

# %%
# Plot the coordinates on a 64x16 grid with colormap
fig = plot_coordinates_with_cmap(region3_list, region = 'heel area')
fig

# %% [markdown]
# # Frame in a foot cycle

# %%
#%%
DM = DataManager()
# available_ID_list = DM.ID_list #Get all available list
available_ID_list = ['GAIT102324-01'] # or type in manually
valid_files = DM.get_valid_data_file_dict(available_ID_list)

# Set up investigation dataset
viewer_idx = 0
file = valid_files[viewer_idx]
data = sio.loadmat(file['path'])
insoleAll_l = data['insoleAll_l'].astype(np.float64)
insoleAll_r = data['insoleAll_r'].astype(np.float64)
t_insole_l = data['t_insole_l'].astype(np.float64)
t_insole_r = data['t_insole_r'].astype(np.float64)

# %%
# Mid Stance
centroids, labels, fig = calculate_centroid(reshape_insole_grid(insoleAll_l[1030]), region_threshold = 5, return_fig = True, apply_GF=False)
fig

# %%
# Mid Stance
centroids, labels, fig = calculate_centroid(reshape_insole_grid(insoleAll_l[1055]), region_threshold = 5, return_fig = True, apply_GF=False)
fig
